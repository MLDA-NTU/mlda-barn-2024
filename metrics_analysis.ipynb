# %%
import pandas as pd
import numpy as np
import seaborn as sb

# %%
FILE = "/home/mlda/jackal_ws/src/mlda-barn-2024/mlda.csv"
data = pd.read_csv(FILE, delimiter=" ", header=None)
data.columns = ["World", "Success", "Collided", "Timeout", "Duration", "Metrics"]
data
# Out:
#      World  Success  Collided  Timeout  Duration  Metrics
# 0        0        1         0        0    16.305   0.4119
# 1        1        1         0        0    17.353   0.3548
# 2        2        1         0        0    16.150   0.3944
# 3        3        1         0        0    15.331   0.3856
# 4        4        1         0        0    16.990   0.3491
# ..     ...      ...       ...      ...       ...      ...
# 212    212        1         0        0    14.496   0.3801
# 213    213        1         0        0    17.536   0.3036
# 214    214        1         0        0    20.322   0.2965
# 215    215        1         0        0    19.113   0.2912
# 216    216        1         0        0    19.407   0.2913
#
# [217 rows x 6 columns]

# %%
print(data["Metrics"].describe())
print("Number of maximum success", data[data["Metrics"] == 0.25]["Metrics"].count(),"/ 1200")
print("Number of Collision", data[data["Collided"] == 1]["Collided"].count(), "/ 1200")
# Out:
# count    217.000000
# mean       0.297292
# std        0.095179
# min        0.000000
# 25%        0.291100
# 50%        0.311900
# 75%        0.348400
# max        0.461400
# Name: Metrics, dtype: float64
# Number of maximum success 0 / 1200
# Number of Collision 23 / 1200

# %%
data_non_max = data[(data["Metrics"]!= 0.25) & (data["Collided"] != 1)]
print("Number of non-collided, non-max: ", data_non_max["World"].count())
data_non_max
# Out:
# Number of non-collided, non-max:  194
#      World  Success  Collided  Timeout  Duration  Metrics
# 0        0        1         0        0    16.305   0.4119
# 1        1        1         0        0    17.353   0.3548
# 2        2        1         0        0    16.150   0.3944
# 3        3        1         0        0    15.331   0.3856
# 4        4        1         0        0    16.990   0.3491
# ..     ...      ...       ...      ...       ...      ...
# 212    212        1         0        0    14.496   0.3801
# 213    213        1         0        0    17.536   0.3036
# 214    214        1         0        0    20.322   0.2965
# 215    215        1         0        0    19.113   0.2912
# 216    216        1         0        0    19.407   0.2913
#
# [194 rows x 6 columns]

# %%
data_collided = data[(data["Collided"] == 1)]
data_collided
# Out:
#       World  Success  Collided  Timeout  Duration  Metrics
# 48       48        0         1        0     6.438      0.0
# 58       58        0         1        0     9.489      0.0
# 163     163        0         1        0     6.998      0.0
# 176     176        0         1        0    10.169      0.0
# 242     242        0         1        0    20.460      0.0
# 254     254        0         1        0     7.889      0.0
# 259     259        0         1        0     6.043      0.0
# 278     278        0         1        0     7.435      0.0
# 282     282        0         1        0     7.460      0.0
# 358      58        0         1        0     7.065      0.0
# 385      85        0         1        0     6.962      0.0
# 438     138        0         1        0     5.628      0.0
# 463     163        0         1        0     8.825      0.0
# 476     176        0         1        0     6.380      0.0
# 514     214        0         1        0     5.176      0.0
# ...
